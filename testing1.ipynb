# %%
from omniindex.api import OmniIndexClient

# %%
client = OmniIndexClient(
    server="https://node1.omniindex.xyz-node",
    api_key="MjkzMjc5MjU0MjExqw3rty==",
    unit_name="futurexschools",
    block_type="Owner",
    user="this is me"
)

response_text = client.get_block_schematic()
print(response_text)
# Out:
# {
# "0" : {
#
# "column_name": "addresscoordinates_typeowners",
# "data_type": "text"
# },
# "1" : {
#
# "column_name": "addresscoordinates_typesearchableowners",
# "data_type": "text"
# },
# "2" : {
#
# "column_name": "attendance_averageattendanceowners",
# "data_type": "text"
# },
# "3" : {
#
# "column_name": "attendance_averageattendancesearchableowners",
# "data_type": "text"
# },
# "4" : {
#
# "column_name": "attendance_classarm_oid",
# "data_type": "text"
# },
# "5" : {
#
# "column_name": "attendance_dateowners",
# "data_type": "text"
# },
# "6" : {
#
# "column_name": "attendance_datesearchableowners",
# "data_type": "text"
# },
# "7" : {
#
# "column_name": "attendance_expirydate_owners",
# "data_type": "text"
# },
# "8" : {
#
# "column_name": "attendance_expirydate_searchableowners",
# "data_type": "text"
# },
# "9" : {
#
# "column_name": "attendance_id_oid",
# "data_type": "text"
# },
# "10" : {
#
# "column_name": "attendance_school_oid",
# "data_type": "text"
# },
# ...
